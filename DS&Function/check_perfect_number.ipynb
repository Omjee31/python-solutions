# %% [markdown]
# Check if a number is perfect, deficient, or abundant.

# %%
def check_Number_perfect(n):
     
    if n<1: # ensuring that number is non negative 
        return False
        
    lst = [i for i in range (1,n) if n%i==0] # list Comprehension to collect all proper divisor
    lst_sum = sum(lst)  # sum of all collected Divisor

    if lst_sum == n:  # if sum of divisors == number ---> perfect number
        return f"{n} Is Perfect Nummber:"
        
    elif lst_sum > n:   # if sum of divisors is greater than number --->Abundant number
        return f"{n} Is Abundant Number:"

    else:    #If sum of divisors is less than number --->deficent number
        return f"{n} Is deficent Number:"
number = int(input("Enter Number You Want To Check It Is perfect/abundant/deficent:
print(check(28))
# Out:
# 28 Is Perfect Nummber:
